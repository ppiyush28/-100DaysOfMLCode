# %%
import pandas as pd

# %%
nba = pd.read_csv("C:/Users/piyush/Downloads/pandas/nba.csv")

# %% [markdown]
# ## Shared Methods and Attributes

# %%
nba = pd.read_csv("C:/Users/piyush/Downloads/pandas/nba.csv")

# %%
nba.head(115)
# Out:
#                          Name                   Team  Number Position   Age  \
# 0               Avery Bradley         Boston Celtics     0.0       PG  25.0
# 1                 Jae Crowder         Boston Celtics    99.0       SF  25.0
# 2                John Holland         Boston Celtics    30.0       SG  27.0
# 3                 R.J. Hunter         Boston Celtics    28.0       SG  22.0
# 4               Jonas Jerebko         Boston Celtics     8.0       PF  29.0
# 5                Amir Johnson         Boston Celtics    90.0       PF  29.0
# 6               Jordan Mickey         Boston Celtics    55.0       PF  21.0
# 7                Kelly Olynyk         Boston Celtics    41.0        C  25.0
# 8                Terry Rozier         Boston Celtics    12.0       PG  22.0
# 9                Marcus Smart         Boston Celtics    36.0       PG  22.0
# 10            Jared Sullinger         Boston Celtics     7.0        C  24.0
# 11              Isaiah Thomas         Boston Celtics     4.0       PG  27.0
# 12                Evan Turner         Boston Celtics    11.0       SG  27.0
# 13                James Young         Boston Celtics    13.0       SG  20.0
# 14               Tyler Zeller         Boston Celtics    44.0        C  26.0
# 15           Bojan Bogdanovic          Brooklyn Nets    44.0       SG  27.0
# 16               Markel Brown          Brooklyn Nets    22.0       SG  24.0
# 17            Wayne Ellington          Brooklyn Nets    21.0       SG  28.0
# 18    Rondae Hollis-Jefferson          Brooklyn Nets    24.0       SG  21.0
# 19               Jarrett Jack          Brooklyn Nets     2.0       PG  32.0
# 20             Sergey Karasev          Brooklyn Nets    10.0       SG  22.0
# 21            Sean Kilpatrick          Brooklyn Nets     6.0       SG  26.0
# 22               Shane Larkin          Brooklyn Nets     0.0       PG  23.0
# 23                Brook Lopez          Brooklyn Nets    11.0        C  28.0
# 24           Chris McCullough          Brooklyn Nets     1.0       PF  21.0
# 25                Willie Reed          Brooklyn Nets    33.0       PF  26.0
# 26            Thomas Robinson          Brooklyn Nets    41.0       PF  25.0
# 27                 Henry Sims          Brooklyn Nets    14.0        C  26.0
# 28               Donald Sloan          Brooklyn Nets    15.0       PG  28.0
# 29             Thaddeus Young          Brooklyn Nets    30.0       PF  27.0
# ..                        ...                    ...     ...      ...   ...
# 85               Kevon Looney  Golden State Warriors    36.0       SF  20.0
# 86       James Michael McAdoo  Golden State Warriors    20.0       SF  23.0
# 87               Brandon Rush  Golden State Warriors     4.0       SF  30.0
# 88          Marreese Speights  Golden State Warriors     5.0        C  28.0
# 89              Klay Thompson  Golden State Warriors    11.0       SG  26.0
# 90           Anderson Varejao  Golden State Warriors    18.0       PF  33.0
# 91               Cole Aldrich   Los Angeles Clippers    45.0        C  27.0
# 92                 Jeff Ayres   Los Angeles Clippers    19.0       PF  29.0
# 93             Jamal Crawford   Los Angeles Clippers    11.0       SG  36.0
# 94             Branden Dawson   Los Angeles Clippers    22.0       SF  23.0
# 95                 Jeff Green   Los Angeles Clippers     8.0       SF  29.0
# 96              Blake Griffin   Los Angeles Clippers    32.0       PF  27.0
# 97             Wesley Johnson   Los Angeles Clippers    33.0       SF  28.0
# 98             DeAndre Jordan   Los Angeles Clippers     6.0        C  27.0
# 99   Luc Richard Mbah a Moute   Los Angeles Clippers    12.0       PF  29.0
# 100                Chris Paul   Los Angeles Clippers     3.0       PG  31.0
# 101               Paul Pierce   Los Angeles Clippers    34.0       SF  38.0
# 102            Pablo Prigioni   Los Angeles Clippers     9.0       PG  39.0
# 103                 JJ Redick   Los Angeles Clippers     4.0       SG  31.0
# 104             Austin Rivers   Los Angeles Clippers    25.0       PG  23.0
# 105               C.J. Wilcox   Los Angeles Clippers    30.0       SG  25.0
# 106              Brandon Bass     Los Angeles Lakers     2.0       PF  31.0
# 107               Tarik Black     Los Angeles Lakers    28.0        C  24.0
# 108             Anthony Brown     Los Angeles Lakers     3.0       SF  23.0
# 109               Kobe Bryant     Los Angeles Lakers    24.0       SF  37.0
# 110           Jordan Clarkson     Los Angeles Lakers     6.0       PG  24.0
# 111               Roy Hibbert     Los Angeles Lakers    17.0        C  29.0
# 112           Marcelo Huertas     Los Angeles Lakers     9.0       PG  33.0
# 113                Ryan Kelly     Los Angeles Lakers     4.0       PF  25.0
# 114           Larry Nance Jr.     Los Angeles Lakers     7.0       PF  23.0
#
#     Height  Weight            College      Salary
# 0      6-2   180.0              Texas   7730337.0
# 1      6-6   235.0          Marquette   6796117.0
# 2      6-5   205.0  Boston University         NaN
# 3      6-5   185.0      Georgia State   1148640.0
# 4     6-10   231.0                NaN   5000000.0
# 5      6-9   240.0                NaN  12000000.0
# 6      6-8   235.0                LSU   1170960.0
# 7      7-0   238.0            Gonzaga   2165160.0
# 8      6-2   190.0         Louisville   1824360.0
# 9      6-4   220.0     Oklahoma State   3431040.0
# 10     6-9   260.0         Ohio State   2569260.0
# 11     5-9   185.0         Washington   6912869.0
# 12     6-7   220.0         Ohio State   3425510.0
# 13     6-6   215.0           Kentucky   1749840.0
# 14     7-0   253.0     North Carolina   2616975.0
# 15     6-8   216.0                NaN   3425510.0
# 16     6-3   190.0     Oklahoma State    845059.0
# 17     6-4   200.0     North Carolina   1500000.0
# 18     6-7   220.0            Arizona   1335480.0
# 19     6-3   200.0       Georgia Tech   6300000.0
# 20     6-7   208.0                NaN   1599840.0
# 21     6-4   219.0         Cincinnati    134215.0
# 22    5-11   175.0         Miami (FL)   1500000.0
# 23     7-0   275.0           Stanford  19689000.0
# 24    6-11   200.0           Syracuse   1140240.0
# 25    6-10   220.0        Saint Louis    947276.0
# 26    6-10   237.0             Kansas    981348.0
# 27    6-10   248.0         Georgetown    947276.0
# 28     6-3   205.0          Texas A&M    947276.0
# 29     6-8   221.0       Georgia Tech  11235955.0
# ..     ...     ...                ...         ...
# 85     6-9   220.0               UCLA   1131960.0
# 86     6-9   240.0     North Carolina    845059.0
# 87     6-6   220.0             Kansas   1270964.0
# 88    6-10   255.0            Florida   3815000.0
# 89     6-7   215.0   Washington State  15501000.0
# 90    6-11   273.0                NaN    289755.0
# 91    6-11   250.0             Kansas   1100602.0
# 92     6-9   250.0      Arizona State    111444.0
# 93     6-5   195.0           Michigan   5675000.0
# 94     6-6   225.0     Michigan State    525093.0
# 95     6-9   235.0         Georgetown   9650000.0
# 96    6-10   251.0           Oklahoma  18907726.0
# 97     6-7   215.0           Syracuse   1100602.0
# 98    6-11   265.0          Texas A&M  19689000.0
# 99     6-8   230.0               UCLA    947276.0
# 100    6-0   175.0        Wake Forest  21468695.0
# 101    6-7   235.0             Kansas   3376000.0
# 102    6-3   185.0                NaN    947726.0
# 103    6-4   190.0               Duke   7085000.0
# 104    6-4   200.0               Duke   3110796.0
# 105    6-5   195.0         Washington   1159680.0
# 106    6-8   250.0                LSU   3000000.0
# 107    6-9   250.0             Kansas    845059.0
# 108    6-7   210.0           Stanford    700000.0
# 109    6-6   212.0                NaN  25000000.0
# 110    6-5   194.0           Missouri    845059.0
# 111    7-2   270.0         Georgetown  15592217.0
# 112    6-3   200.0                NaN    525093.0
# 113   6-11   230.0               Duke   1724250.0
# 114    6-9   230.0            Wyoming   1155600.0
#
# [115 rows x 9 columns]

# %%
nba.tail(31)
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 427   Cliff Alexander  Portland Trail Blazers    34.0       PF  20.0    6-8
# 428   Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0    6-9
# 429   Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0    6-5
# 430      Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0    6-6
# 431          Ed Davis  Portland Trail Blazers    17.0        C  27.0   6-10
# 432  Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0    6-9
# 433  Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0    6-5
# 434       Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
# 435    Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0    7-1
# 436    Damian Lillard  Portland Trail Blazers     0.0       PG  25.0    6-3
# 437     C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0    6-4
# 438      Luis Montero  Portland Trail Blazers    44.0       SG  23.0    6-7
# 439     Mason Plumlee  Portland Trail Blazers    24.0        C  26.0   6-11
# 440     Brian Roberts  Portland Trail Blazers     2.0       PG  30.0    6-1
# 441       Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0    6-9
# 442     Trevor Booker               Utah Jazz    33.0       PF  28.0    6-8
# 443        Trey Burke               Utah Jazz     3.0       PG  23.0    6-1
# 444        Alec Burks               Utah Jazz    10.0       SG  24.0    6-6
# 445        Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 446    Derrick Favors               Utah Jazz    15.0       PF  24.0   6-10
# 447       Rudy Gobert               Utah Jazz    27.0        C  23.0    7-1
# 448    Gordon Hayward               Utah Jazz    20.0       SF  26.0    6-8
# 449       Rodney Hood               Utah Jazz     5.0       SG  23.0    6-8
# 450        Joe Ingles               Utah Jazz     2.0       SF  28.0    6-8
# 451     Chris Johnson               Utah Jazz    23.0       SF  26.0    6-6
# 452        Trey Lyles               Utah Jazz    41.0       PF  20.0   6-10
# 453      Shelvin Mack               Utah Jazz     8.0       PG  26.0    6-3
# 454         Raul Neto               Utah Jazz    25.0       PG  24.0    6-1
# 455      Tibor Pleiss               Utah Jazz    21.0        C  26.0    7-3
# 456       Jeff Withey               Utah Jazz    24.0        C  26.0    7-0
# 457               NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight           College      Salary
# 427   240.0            Kansas    525093.0
# 428   215.0       Wake Forest   8042895.0
# 429   206.0        Notre Dame    625093.0
# 430   210.0        California    947276.0
# 431   240.0    North Carolina   6980802.0
# 432   215.0        St. John's   2894059.0
# 433   215.0              Duke   6000000.0
# 434   265.0  Central Michigan   5016000.0
# 435   245.0          Illinois   3075880.0
# 436   195.0       Weber State   4236287.0
# 437   200.0            Lehigh   2525160.0
# 438   185.0    Westchester CC    525093.0
# 439   235.0              Duke   1415520.0
# 440   173.0            Dayton   2854940.0
# 441   240.0           Indiana   2637720.0
# 442   228.0           Clemson   4775000.0
# 443   191.0          Michigan   2658240.0
# 444   214.0          Colorado   9463484.0
# 445   190.0               NaN   3777720.0
# 446   265.0      Georgia Tech  12000000.0
# 447   245.0               NaN   1175880.0
# 448   226.0            Butler  15409570.0
# 449   206.0              Duke   1348440.0
# 450   226.0               NaN   2050000.0
# 451   206.0            Dayton    981348.0
# 452   234.0          Kentucky   2239800.0
# 453   203.0            Butler   2433333.0
# 454   179.0               NaN    900000.0
# 455   256.0               NaN   2900000.0
# 456   231.0            Kansas    947276.0
# 457     NaN               NaN         NaN

# %%
conda update --all
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\piyush\Anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           6 KB
#     anaconda-custom            |           py37_1           3 KB
#     bokeh-1.3.4                |           py37_0         6.7 MB
#     ca-certificates-2019.5.15  |                1         166 KB
#     certifi-2019.6.16          |           py37_1         156 KB
#     chardet-3.0.4              |        py37_1003         192 KB
#     conda-4.7.11               |           py37_0         3.0 MB
#     conda-build-3.18.9         |           py37_0         531 KB
#     dask-2.2.0                 |             py_0          12 KB
#     dask-core-2.2.0            |             py_0         573 KB
#     distributed-2.2.0          |             py_1         372 KB
#     docutils-0.15.1            |           py37_0         744 KB
#     fsspec-0.4.0               |             py_0          41 KB
#     importlib_metadata-0.19    |           py37_0          41 KB
#     ipython-7.7.0              |   py37h39e3cac_0         1.1 MB
#     ipywidgets-7.5.1           |             py_0         107 KB
#     json5-0.8.5                |             py_0          25 KB
#     jupyterlab_server-1.0.0    |             py_1          25 KB
#     more-itertools-7.2.0       |           py37_0          99 KB
#     numba-0.45.1               |   py37hf9181ef_0         3.0 MB
#     pandas-0.25.0              |   py37ha925a31_0         9.8 MB
#     pytest-remotedata-0.3.2    |           py37_0          15 KB
#     python-3.7.4               |       h5263a28_0        18.2 MB
#     python-libarchive-c-2.8    |          py37_13          24 KB
#     qtconsole-4.5.2            |             py_0          92 KB
#     scipy-1.3.0                |   py37h29ff71c_0        14.3 MB
#     soupsieve-1.9.2            |           py37_0          61 KB
#     statsmodels-0.10.1         |   py37h8c2d366_0         8.9 MB
#     zipp-0.5.2                 |             py_0           8 KB
#     ------------------------------------------------------------
#                                            Total:        68.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2019.03-py37_0
#   fsspec             pkgs/main/noarch::fsspec-0.4.0-py_0
#
# The following packages will be UPDATED:
#
#   bokeh                                        1.2.0-py37_0 --> 1.3.4-py37_0
#   ca-certificates                               2019.5.15-0 --> 2019.5.15-1
#   certifi                                  2019.6.16-py37_0 --> 2019.6.16-py37_1
#   chardet                                      3.0.4-py37_1 --> 3.0.4-py37_1003
#   conda                                       4.7.10-py37_0 --> 4.7.11-py37_0
#   conda-build                                 3.18.8-py37_0 --> 3.18.9-py37_0
#   dask                                           2.1.0-py_0 --> 2.2.0-py_0
#   dask-core                                      2.1.0-py_0 --> 2.2.0-py_0
#   distributed                                    2.1.0-py_0 --> 2.2.0-py_1
#   docutils                                      0.14-py37_0 --> 0.15.1-py37_0
#   importlib_metadata                            0.17-py37_1 --> 0.19-py37_0
#   ipython                              7.6.1-py37h39e3cac_0 --> 7.7.0-py37h39e3cac_0
#   ipywidgets                                     7.5.0-py_0 --> 7.5.1-py_0
#   json5                                          0.8.4-py_0 --> 0.8.5-py_0
#   jupyterlab_server                              1.0.0-py_0 --> 1.0.0-py_1
#   more-itertools                               7.0.0-py37_0 --> 7.2.0-py37_0
#   numba                               0.44.1-py37hf9181ef_0 --> 0.45.1-py37hf9181ef_0
#   pandas                              0.24.2-py37ha925a31_0 --> 0.25.0-py37ha925a31_0
#   pytest-remotedata                            0.3.1-py37_0 --> 0.3.2-py37_0
#   python                                   3.7.3-h8c8aaf0_1 --> 3.7.4-h5263a28_0
#   python-libarchive~                            2.8-py37_11 --> 2.8-py37_13
#   qtconsole                                      4.5.1-py_0 --> 4.5.2-py_0
#   scipy                                1.2.1-py37h29ff71c_0 --> 1.3.0-py37h29ff71c_0
#   soupsieve                                      1.8-py37_0 --> 1.9.2-py37_0
#   statsmodels                         0.10.0-py37h8c2d366_0 --> 0.10.1-py37h8c2d366_0
#   zipp                                           0.5.1-py_0 --> 0.5.2-py_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2019.07-py37_0 --> custom-py37_1
#
#
#
# Downloading and Extracting Packages
#
# certifi-2019.6.16    | 156 KB    |            |   0%
# certifi-2019.6.16    | 156 KB    | #####1     |  51%
# certifi-2019.6.16    | 156 KB    | ########## | 100%
#
# conda-4.7.11         | 3.0 MB    |            |   0%
# conda-4.7.11         | 3.0 MB    | 7          |   7%
# conda-4.7.11         | 3.0 MB    | #2         |  12%
# conda-4.7.11         | 3.0 MB    | #7         |  17%
# conda-4.7.11         | 3.0 MB    | ##1        |  22%
# conda-4.7.11         | 3.0 MB    | ##6        |  26%
# conda-4.7.11         | 3.0 MB    | ###        |  31%
# conda-4.7.11         | 3.0 MB    | ###4       |  35%
# conda-4.7.11         | 3.0 MB    | ###8       |  39%
# conda-4.7.11         | 3.0 MB    | ####3      |  43%
# conda-4.7.11         | 3.0 MB    | ####7      |  47%
# conda-4.7.11         | 3.0 MB    | #####1     |  51%
# conda-4.7.11         | 3.0 MB    | #####5     |  56%
# conda-4.7.11         | 3.0 MB    | #####9     |  60%
# conda-4.7.11         | 3.0 MB    | ######4    |  64%
# conda-4.7.11         | 3.0 MB    | ######8    |  69%
# conda-4.7.11         | 3.0 MB    | #######2   |  73%
# conda-4.7.11         | 3.0 MB    | #######6   |  77%
# conda-4.7.11         | 3.0 MB    | ########1  |  81%
# conda-4.7.11         | 3.0 MB    | ########5  |  85%
# conda-4.7.11         | 3.0 MB    | ########9  |  89%
# conda-4.7.11         | 3.0 MB    | #########3 |  94%
# conda-4.7.11         | 3.0 MB    | #########7 |  98%
# conda-4.7.11         | 3.0 MB    | ########## | 100%
#
# ipywidgets-7.5.1     | 107 KB    |            |   0%
# ipywidgets-7.5.1     | 107 KB    | ########## | 100%
#
# pytest-remotedata-0. | 15 KB     |            |   0%
# pytest-remotedata-0. | 15 KB     | ########## | 100%
#
# statsmodels-0.10.1   | 8.9 MB    |            |   0%
# statsmodels-0.10.1   | 8.9 MB    | 2          |   2%
# statsmodels-0.10.1   | 8.9 MB    | 3          |   3%
# statsmodels-0.10.1   | 8.9 MB    | 4          |   5%
# statsmodels-0.10.1   | 8.9 MB    | 6          |   7%
# statsmodels-0.10.1   | 8.9 MB    | 8          |   8%
# statsmodels-0.10.1   | 8.9 MB    | 9          |   9%
# statsmodels-0.10.1   | 8.9 MB    | #          |  11%
# statsmodels-0.10.1   | 8.9 MB    | #2         |  12%
# statsmodels-0.10.1   | 8.9 MB    | #3         |  14%
# statsmodels-0.10.1   | 8.9 MB    | #5         |  15%
# statsmodels-0.10.1   | 8.9 MB    | #6         |  17%
# statsmodels-0.10.1   | 8.9 MB    | #8         |  18%
# statsmodels-0.10.1   | 8.9 MB    | #9         |  19%
# statsmodels-0.10.1   | 8.9 MB    | ##         |  21%
# statsmodels-0.10.1   | 8.9 MB    | ##2        |  23%
# statsmodels-0.10.1   | 8.9 MB    | ##4        |  25%
# statsmodels-0.10.1   | 8.9 MB    | ##6        |  26%
# statsmodels-0.10.1   | 8.9 MB    | ##8        |  29%
# statsmodels-0.10.1   | 8.9 MB    | ###        |  30%
# statsmodels-0.10.1   | 8.9 MB    | ###2       |  32%
# statsmodels-0.10.1   | 8.9 MB    | ###3       |  34%
# statsmodels-0.10.1   | 8.9 MB    | ###5       |  35%
# statsmodels-0.10.1   | 8.9 MB    | ###6       |  37%
# statsmodels-0.10.1   | 8.9 MB    | ###8       |  38%
# statsmodels-0.10.1   | 8.9 MB    | ####       |  40%
# statsmodels-0.10.1   | 8.9 MB    | ####1      |  42%
# statsmodels-0.10.1   | 8.9 MB    | ####3      |  43%
# statsmodels-0.10.1   | 8.9 MB    | ####4      |  45%
# statsmodels-0.10.1   | 8.9 MB    | ####6      |  47%
# statsmodels-0.10.1   | 8.9 MB    | ####8      |  48%
# statsmodels-0.10.1   | 8.9 MB    | ####9      |  50%
# statsmodels-0.10.1   | 8.9 MB    | #####      |  51%
# statsmodels-0.10.1   | 8.9 MB    | #####2     |  52%
# statsmodels-0.10.1   | 8.9 MB    | #####3     |  54%
# statsmodels-0.10.1   | 8.9 MB    | #####5     |  55%
# statsmodels-0.10.1   | 8.9 MB    | #####6     |  57%
# statsmodels-0.10.1   | 8.9 MB    | #####7     |  58%
# statsmodels-0.10.1   | 8.9 MB    | #####9     |  59%
# statsmodels-0.10.1   | 8.9 MB    | ######     |  61%
# statsmodels-0.10.1   | 8.9 MB    | ######2    |  62%
# statsmodels-0.10.1   | 8.9 MB    | ######3    |  64%
# statsmodels-0.10.1   | 8.9 MB    | ######4    |  65%
# statsmodels-0.10.1   | 8.9 MB    | ######6    |  66%
# statsmodels-0.10.1   | 8.9 MB    | ######7    |  68%
# statsmodels-0.10.1   | 8.9 MB    | ######9    |  69%
# statsmodels-0.10.1   | 8.9 MB    | #######    |  71%
# statsmodels-0.10.1   | 8.9 MB    | #######2   |  72%
# statsmodels-0.10.1   | 8.9 MB    | #######3   |  73%
# statsmodels-0.10.1   | 8.9 MB    | #######4   |  75%
# statsmodels-0.10.1   | 8.9 MB    | #######6   |  76%
# statsmodels-0.10.1   | 8.9 MB    | #######7   |  78%
# statsmodels-0.10.1   | 8.9 MB    | #######9   |  79%
# statsmodels-0.10.1   | 8.9 MB    | ########   |  80%
# statsmodels-0.10.1   | 8.9 MB    | ########1  |  82%
# statsmodels-0.10.1   | 8.9 MB    | ########3  |  83%
# statsmodels-0.10.1   | 8.9 MB    | ########4  |  85%
# statsmodels-0.10.1   | 8.9 MB    | ########6  |  86%
# statsmodels-0.10.1   | 8.9 MB    | ########7  |  87%
# statsmodels-0.10.1   | 8.9 MB    | ########8  |  89%
# statsmodels-0.10.1   | 8.9 MB    | #########  |  90%
# statsmodels-0.10.1   | 8.9 MB    | #########1 |  92%
# statsmodels-0.10.1   | 8.9 MB    | #########3 |  93%
# statsmodels-0.10.1   | 8.9 MB    | #########4 |  95%
# statsmodels-0.10.1   | 8.9 MB    | #########5 |  96%
# statsmodels-0.10.1   | 8.9 MB    | #########7 |  97%
# statsmodels-0.10.1   | 8.9 MB    | #########8 |  99%
# statsmodels-0.10.1   | 8.9 MB    | ########## | 100%
#
# more-itertools-7.2.0 | 99 KB     |            |   0%
# more-itertools-7.2.0 | 99 KB     | ########## | 100%
#
# pandas-0.25.0        | 9.8 MB    |            |   0%
# pandas-0.25.0        | 9.8 MB    | 1          |   2%
# pandas-0.25.0        | 9.8 MB    | 2          |   3%
# pandas-0.25.0        | 9.8 MB    | 4          |   4%
# pandas-0.25.0        | 9.8 MB    | 5          |   6%
# pandas-0.25.0        | 9.8 MB    | 7          |   7%
# pandas-0.25.0        | 9.8 MB    | 8          |   8%
# pandas-0.25.0        | 9.8 MB    | 9          |  10%
# pandas-0.25.0        | 9.8 MB    | #1         |  11%
# pandas-0.25.0        | 9.8 MB    | #2         |  12%
# pandas-0.25.0        | 9.8 MB    | #3         |  14%
# pandas-0.25.0        | 9.8 MB    | #4         |  15%
# pandas-0.25.0        | 9.8 MB    | #6         |  16%
# pandas-0.25.0        | 9.8 MB    | #8         |  18%
# pandas-0.25.0        | 9.8 MB    | #9         |  20%
# pandas-0.25.0        | 9.8 MB    | ##1        |  22%
# pandas-0.25.0        | 9.8 MB    | ##2        |  23%
# pandas-0.25.0        | 9.8 MB    | ##4        |  24%
# pandas-0.25.0        | 9.8 MB    | ##5        |  26%
# pandas-0.25.0        | 9.8 MB    | ##7        |  27%
# pandas-0.25.0        | 9.8 MB    | ##8        |  29%
# pandas-0.25.0        | 9.8 MB    | ##9        |  30%
# pandas-0.25.0        | 9.8 MB    | ###1       |  31%
# pandas-0.25.0        | 9.8 MB    | ###2       |  33%
# pandas-0.25.0        | 9.8 MB    | ###3       |  34%
# pandas-0.25.0        | 9.8 MB    | ###5       |  35%
# pandas-0.25.0        | 9.8 MB    | ###6       |  36%
# pandas-0.25.0        | 9.8 MB    | ###7       |  38%
# pandas-0.25.0        | 9.8 MB    | ###8       |  39%
# pandas-0.25.0        | 9.8 MB    | ####       |  40%
# pandas-0.25.0        | 9.8 MB    | ####1      |  41%
# pandas-0.25.0        | 9.8 MB    | ####2      |  43%
# pandas-0.25.0        | 9.8 MB    | ####4      |  44%
# pandas-0.25.0        | 9.8 MB    | ####5      |  45%
# pandas-0.25.0        | 9.8 MB    | ####6      |  47%
# pandas-0.25.0        | 9.8 MB    | ####7      |  48%
# pandas-0.25.0        | 9.8 MB    | ####9      |  49%
# pandas-0.25.0        | 9.8 MB    | #####      |  51%
# pandas-0.25.0        | 9.8 MB    | #####1     |  52%
# pandas-0.25.0        | 9.8 MB    | #####3     |  53%
# pandas-0.25.0        | 9.8 MB    | #####4     |  55%
# pandas-0.25.0        | 9.8 MB    | #####5     |  56%
# pandas-0.25.0        | 9.8 MB    | #####7     |  57%
# pandas-0.25.0        | 9.8 MB    | #####8     |  59%
# pandas-0.25.0        | 9.8 MB    | ######     |  60%
# pandas-0.25.0        | 9.8 MB    | ######1    |  62%
# pandas-0.25.0        | 9.8 MB    | ######2    |  63%
# pandas-0.25.0        | 9.8 MB    | ######4    |  64%
# pandas-0.25.0        | 9.8 MB    | ######5    |  65%
# pandas-0.25.0        | 9.8 MB    | ######6    |  67%
# pandas-0.25.0        | 9.8 MB    | ######7    |  68%
# pandas-0.25.0        | 9.8 MB    | ######9    |  69%
# pandas-0.25.0        | 9.8 MB    | #######    |  70%
# pandas-0.25.0        | 9.8 MB    | #######1   |  72%
# pandas-0.25.0        | 9.8 MB    | #######3   |  73%
# pandas-0.25.0        | 9.8 MB    | #######4   |  74%
# pandas-0.25.0        | 9.8 MB    | #######5   |  76%
# pandas-0.25.0        | 9.8 MB    | #######7   |  77%
# pandas-0.25.0        | 9.8 MB    | #######8   |  78%
# pandas-0.25.0        | 9.8 MB    | #######9   |  80%
# pandas-0.25.0        | 9.8 MB    | ########   |  81%
# pandas-0.25.0        | 9.8 MB    | ########2  |  82%
# pandas-0.25.0        | 9.8 MB    | ########3  |  84%
# pandas-0.25.0        | 9.8 MB    | ########4  |  85%
# pandas-0.25.0        | 9.8 MB    | ########6  |  86%
# pandas-0.25.0        | 9.8 MB    | ########7  |  87%
# pandas-0.25.0        | 9.8 MB    | ########8  |  89%
# pandas-0.25.0        | 9.8 MB    | ########9  |  90%
# pandas-0.25.0        | 9.8 MB    | #########1 |  91%
# pandas-0.25.0        | 9.8 MB    | #########2 |  92%
# pandas-0.25.0        | 9.8 MB    | #########3 |  94%
# pandas-0.25.0        | 9.8 MB    | #########5 |  95%
# pandas-0.25.0        | 9.8 MB    | #########6 |  96%
# pandas-0.25.0        | 9.8 MB    | #########7 |  98%
# pandas-0.25.0        | 9.8 MB    | #########8 |  99%
# pandas-0.25.0        | 9.8 MB    | ########## | 100%
#
# qtconsole-4.5.2      | 92 KB     |            |   0%
# qtconsole-4.5.2      | 92 KB     | ########## | 100%
#
# numba-0.45.1         | 3.0 MB    |            |   0%
# numba-0.45.1         | 3.0 MB    | 5          |   5%
# numba-0.45.1         | 3.0 MB    | 8          |   9%
# numba-0.45.1         | 3.0 MB    | #5         |  15%
# numba-0.45.1         | 3.0 MB    | #9         |  19%
# numba-0.45.1         | 3.0 MB    | ##4        |  24%
# numba-0.45.1         | 3.0 MB    | ##8        |  28%
# numba-0.45.1         | 3.0 MB    | ###2       |  33%
# numba-0.45.1         | 3.0 MB    | ###6       |  36%
# numba-0.45.1         | 3.0 MB    | ####       |  40%
# numba-0.45.1         | 3.0 MB    | ####4      |  45%
# numba-0.45.1         | 3.0 MB    | ####8      |  49%
# numba-0.45.1         | 3.0 MB    | #####3     |  54%
# numba-0.45.1         | 3.0 MB    | #####9     |  59%
# numba-0.45.1         | 3.0 MB    | ######5    |  66%
# numba-0.45.1         | 3.0 MB    | #######    |  71%
# numba-0.45.1         | 3.0 MB    | #######5   |  76%
# numba-0.45.1         | 3.0 MB    | ########1  |  82%
# numba-0.45.1         | 3.0 MB    | ########6  |  86%
# numba-0.45.1         | 3.0 MB    | #########  |  91%
# numba-0.45.1         | 3.0 MB    | #########5 |  96%
# numba-0.45.1         | 3.0 MB    | ########## | 100%
#
# ipython-7.7.0        | 1.1 MB    |            |   0%
# ipython-7.7.0        | 1.1 MB    | #7         |  18%
# ipython-7.7.0        | 1.1 MB    | ##3        |  23%
# ipython-7.7.0        | 1.1 MB    | ###7       |  37%
# ipython-7.7.0        | 1.1 MB    | #####1     |  51%
# ipython-7.7.0        | 1.1 MB    | ######2    |  62%
# ipython-7.7.0        | 1.1 MB    | #######4   |  74%
# ipython-7.7.0        | 1.1 MB    | ########5  |  85%
# ipython-7.7.0        | 1.1 MB    | #########6 |  96%
# ipython-7.7.0        | 1.1 MB    | ########## | 100%
#
# distributed-2.2.0    | 372 KB    |            |   0%
# distributed-2.2.0    | 372 KB    | ###        |  30%
# distributed-2.2.0    | 372 KB    | ######4    |  64%
# distributed-2.2.0    | 372 KB    | #########8 |  99%
# distributed-2.2.0    | 372 KB    | ########## | 100%
#
# dask-core-2.2.0      | 573 KB    |            |   0%
# dask-core-2.2.0      | 573 KB    | #9         |  20%
# dask-core-2.2.0      | 573 KB    | #####8     |  59%
# dask-core-2.2.0      | 573 KB    | ########   |  81%
# dask-core-2.2.0      | 573 KB    | ########## | 100%
#
# _anaconda_depends-20 | 6 KB      |            |   0%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
#
# chardet-3.0.4        | 192 KB    |            |   0%
# chardet-3.0.4        | 192 KB    | ########## | 100%
#
# ca-certificates-2019 | 166 KB    |            |   0%
# ca-certificates-2019 | 166 KB    | ########## | 100%
#
# dask-2.2.0           | 12 KB     |            |   0%
# dask-2.2.0           | 12 KB     | ########## | 100%
#
# bokeh-1.3.4          | 6.7 MB    |            |   0%
# bokeh-1.3.4          | 6.7 MB    | 3          |   3%
# bokeh-1.3.4          | 6.7 MB    | 3          |   4%
# bokeh-1.3.4          | 6.7 MB    | 5          |   6%
# bokeh-1.3.4          | 6.7 MB    | 8          |   9%
# bokeh-1.3.4          | 6.7 MB    | #          |  10%
# bokeh-1.3.4          | 6.7 MB    | #2         |  12%
# bokeh-1.3.4          | 6.7 MB    | #4         |  14%
# bokeh-1.3.4          | 6.7 MB    | #6         |  16%
# bokeh-1.3.4          | 6.7 MB    | #7         |  18%
# bokeh-1.3.4          | 6.7 MB    | #9         |  20%
# bokeh-1.3.4          | 6.7 MB    | ##1        |  22%
# bokeh-1.3.4          | 6.7 MB    | ##3        |  23%
# bokeh-1.3.4          | 6.7 MB    | ##5        |  26%
# bokeh-1.3.4          | 6.7 MB    | ##8        |  29%
# bokeh-1.3.4          | 6.7 MB    | ###1       |  31%
# bokeh-1.3.4          | 6.7 MB    | ###3       |  34%
# bokeh-1.3.4          | 6.7 MB    | ###6       |  36%
# bokeh-1.3.4          | 6.7 MB    | ###8       |  38%
# bokeh-1.3.4          | 6.7 MB    | ####       |  41%
# bokeh-1.3.4          | 6.7 MB    | ####2      |  43%
# bokeh-1.3.4          | 6.7 MB    | ####4      |  44%
# bokeh-1.3.4          | 6.7 MB    | ####6      |  47%
# bokeh-1.3.4          | 6.7 MB    | ####8      |  48%
# bokeh-1.3.4          | 6.7 MB    | #####      |  50%
# bokeh-1.3.4          | 6.7 MB    | #####2     |  52%
# bokeh-1.3.4          | 6.7 MB    | #####4     |  55%
# bokeh-1.3.4          | 6.7 MB    | #####6     |  56%
# bokeh-1.3.4          | 6.7 MB    | ######     |  60%
# bokeh-1.3.4          | 6.7 MB    | ######2    |  63%
# bokeh-1.3.4          | 6.7 MB    | ######5    |  66%
# bokeh-1.3.4          | 6.7 MB    | ######8    |  68%
# bokeh-1.3.4          | 6.7 MB    | #######    |  70%
# bokeh-1.3.4          | 6.7 MB    | #######2   |  73%
# bokeh-1.3.4          | 6.7 MB    | #######4   |  75%
# bokeh-1.3.4          | 6.7 MB    | #######6   |  77%
# bokeh-1.3.4          | 6.7 MB    | #######8   |  79%
# bokeh-1.3.4          | 6.7 MB    | ########1  |  81%
# bokeh-1.3.4          | 6.7 MB    | ########3  |  83%
# bokeh-1.3.4          | 6.7 MB    | ########5  |  85%
# bokeh-1.3.4          | 6.7 MB    | ########7  |  87%
# bokeh-1.3.4          | 6.7 MB    | ########8  |  89%
# bokeh-1.3.4          | 6.7 MB    | #########  |  91%
# bokeh-1.3.4          | 6.7 MB    | #########3 |  93%
# bokeh-1.3.4          | 6.7 MB    | #########5 |  96%
# bokeh-1.3.4          | 6.7 MB    | #########7 |  97%
# bokeh-1.3.4          | 6.7 MB    | #########9 |  99%
# bokeh-1.3.4          | 6.7 MB    | ########## | 100%
#
# scipy-1.3.0          | 14.3 MB   |            |   0%
# scipy-1.3.0          | 14.3 MB   | 1          |   1%
# scipy-1.3.0          | 14.3 MB   | 1          |   2%
# scipy-1.3.0          | 14.3 MB   | 3          |   3%
# scipy-1.3.0          | 14.3 MB   | 4          |   4%
# scipy-1.3.0          | 14.3 MB   | 4          |   5%
# scipy-1.3.0          | 14.3 MB   | 5          |   6%
# scipy-1.3.0          | 14.3 MB   | 6          |   7%
# scipy-1.3.0          | 14.3 MB   | 7          |   8%
# scipy-1.3.0          | 14.3 MB   | 8          |   8%
# scipy-1.3.0          | 14.3 MB   | 9          |   9%
# scipy-1.3.0          | 14.3 MB   | #          |  10%
# scipy-1.3.0          | 14.3 MB   | #1         |  11%
# scipy-1.3.0          | 14.3 MB   | #2         |  12%
# scipy-1.3.0          | 14.3 MB   | #3         |  13%
# scipy-1.3.0          | 14.3 MB   | #3         |  14%
# scipy-1.3.0          | 14.3 MB   | #4         |  15%
# scipy-1.3.0          | 14.3 MB   | #5         |  16%
# scipy-1.3.0          | 14.3 MB   | #6         |  17%
# scipy-1.3.0          | 14.3 MB   | #7         |  18%
# scipy-1.3.0          | 14.3 MB   | #8         |  19%
# scipy-1.3.0          | 14.3 MB   | #9         |  19%
# scipy-1.3.0          | 14.3 MB   | ##         |  20%
# scipy-1.3.0          | 14.3 MB   | ##1        |  21%
# scipy-1.3.0          | 14.3 MB   | ##2        |  22%
# scipy-1.3.0          | 14.3 MB   | ##2        |  23%
# scipy-1.3.0          | 14.3 MB   | ##3        |  24%
# scipy-1.3.0          | 14.3 MB   | ##4        |  25%
# scipy-1.3.0          | 14.3 MB   | ##5        |  26%
# scipy-1.3.0          | 14.3 MB   | ##6        |  26%
# scipy-1.3.0          | 14.3 MB   | ##7        |  27%
# scipy-1.3.0          | 14.3 MB   | ##8        |  28%
# scipy-1.3.0          | 14.3 MB   | ##9        |  29%
# scipy-1.3.0          | 14.3 MB   | ##9        |  30%
# scipy-1.3.0          | 14.3 MB   | ###        |  31%
# scipy-1.3.0          | 14.3 MB   | ###1       |  32%
# scipy-1.3.0          | 14.3 MB   | ###2       |  33%
# scipy-1.3.0          | 14.3 MB   | ###3       |  33%
# scipy-1.3.0          | 14.3 MB   | ###4       |  34%
# scipy-1.3.0          | 14.3 MB   | ###5       |  35%
# scipy-1.3.0          | 14.3 MB   | ###6       |  36%
# scipy-1.3.0          | 14.3 MB   | ###6       |  37%
# scipy-1.3.0          | 14.3 MB   | ###7       |  38%
# scipy-1.3.0          | 14.3 MB   | ###8       |  39%
# scipy-1.3.0          | 14.3 MB   | ###9       |  40%
# scipy-1.3.0          | 14.3 MB   | ####       |  40%
# scipy-1.3.0          | 14.3 MB   | ####1      |  41%
# scipy-1.3.0          | 14.3 MB   | ####2      |  42%
# scipy-1.3.0          | 14.3 MB   | ####3      |  43%
# scipy-1.3.0          | 14.3 MB   | ####3      |  44%
# scipy-1.3.0          | 14.3 MB   | ####4      |  45%
# scipy-1.3.0          | 14.3 MB   | ####5      |  46%
# scipy-1.3.0          | 14.3 MB   | ####6      |  47%
# scipy-1.3.0          | 14.3 MB   | ####7      |  47%
# scipy-1.3.0          | 14.3 MB   | ####8      |  48%
# scipy-1.3.0          | 14.3 MB   | ####9      |  49%
# scipy-1.3.0          | 14.3 MB   | #####      |  50%
# scipy-1.3.0          | 14.3 MB   | #####      |  51%
# scipy-1.3.0          | 14.3 MB   | #####1     |  52%
# scipy-1.3.0          | 14.3 MB   | #####2     |  53%
# scipy-1.3.0          | 14.3 MB   | #####3     |  54%
# scipy-1.3.0          | 14.3 MB   | #####4     |  54%
# scipy-1.3.0          | 14.3 MB   | #####5     |  55%
# scipy-1.3.0          | 14.3 MB   | #####6     |  56%
# scipy-1.3.0          | 14.3 MB   | #####7     |  57%
# scipy-1.3.0          | 14.3 MB   | #####7     |  58%
# scipy-1.3.0          | 14.3 MB   | #####8     |  59%
# scipy-1.3.0          | 14.3 MB   | #####9     |  60%
# scipy-1.3.0          | 14.3 MB   | ######     |  61%
# scipy-1.3.0          | 14.3 MB   | ######1    |  61%
# scipy-1.3.0          | 14.3 MB   | ######2    |  62%
# scipy-1.3.0          | 14.3 MB   | ######3    |  63%
# scipy-1.3.0          | 14.3 MB   | ######4    |  64%
# scipy-1.3.0          | 14.3 MB   | ######4    |  65%
# scipy-1.3.0          | 14.3 MB   | ######5    |  66%
# scipy-1.3.0          | 14.3 MB   | ######6    |  67%
# scipy-1.3.0          | 14.3 MB   | ######7    |  68%
# scipy-1.3.0          | 14.3 MB   | ######8    |  68%
# scipy-1.3.0          | 14.3 MB   | ######9    |  69%
# scipy-1.3.0          | 14.3 MB   | #######    |  70%
# scipy-1.3.0          | 14.3 MB   | #######1   |  71%
# scipy-1.3.0          | 14.3 MB   | #######1   |  72%
# scipy-1.3.0          | 14.3 MB   | #######2   |  73%
# scipy-1.3.0          | 14.3 MB   | #######3   |  74%
# scipy-1.3.0          | 14.3 MB   | #######4   |  75%
# scipy-1.3.0          | 14.3 MB   | #######5   |  75%
# scipy-1.3.0          | 14.3 MB   | #######6   |  76%
# scipy-1.3.0          | 14.3 MB   | #######7   |  77%
# scipy-1.3.0          | 14.3 MB   | #######8   |  78%
# scipy-1.3.0          | 14.3 MB   | #######8   |  79%
# scipy-1.3.0          | 14.3 MB   | #######9   |  80%
# scipy-1.3.0          | 14.3 MB   | ########   |  81%
# scipy-1.3.0          | 14.3 MB   | ########1  |  82%
# scipy-1.3.0          | 14.3 MB   | ########2  |  83%
# scipy-1.3.0          | 14.3 MB   | ########3  |  83%
# scipy-1.3.0          | 14.3 MB   | ########4  |  84%
# scipy-1.3.0          | 14.3 MB   | ########5  |  85%
# scipy-1.3.0          | 14.3 MB   | ########6  |  86%
# scipy-1.3.0          | 14.3 MB   | ########7  |  87%
# scipy-1.3.0          | 14.3 MB   | ########8  |  88%
# scipy-1.3.0          | 14.3 MB   | ########9  |  89%
# scipy-1.3.0          | 14.3 MB   | #########  |  90%
# scipy-1.3.0          | 14.3 MB   | #########1 |  91%
# scipy-1.3.0          | 14.3 MB   | #########2 |  92%
# scipy-1.3.0          | 14.3 MB   | #########3 |  93%
# scipy-1.3.0          | 14.3 MB   | #########4 |  94%
# scipy-1.3.0          | 14.3 MB   | #########5 |  95%
# scipy-1.3.0          | 14.3 MB   | #########5 |  96%
# scipy-1.3.0          | 14.3 MB   | #########6 |  97%
# scipy-1.3.0          | 14.3 MB   | #########7 |  98%
# scipy-1.3.0          | 14.3 MB   | #########8 |  99%
# scipy-1.3.0          | 14.3 MB   | #########9 |  99%
# scipy-1.3.0          | 14.3 MB   | ########## | 100%
#
# jupyterlab_server-1. | 25 KB     |            |   0%
# jupyterlab_server-1. | 25 KB     | ########## | 100%
#
# fsspec-0.4.0         | 41 KB     |            |   0%
# fsspec-0.4.0         | 41 KB     | ########## | 100%
#
# zipp-0.5.2           | 8 KB      |            |   0%
# zipp-0.5.2           | 8 KB      | ########## | 100%
#
# python-libarchive-c- | 24 KB     |            |   0%
# python-libarchive-c- | 24 KB     | ########## | 100%
#
# docutils-0.15.1      | 744 KB    |            |   0%
# docutils-0.15.1      | 744 KB    | ##5        |  26%
# docutils-0.15.1      | 744 KB    | ###8       |  39%
# docutils-0.15.1      | 744 KB    | ######     |  60%
# docutils-0.15.1      | 744 KB    | ########3  |  84%
# docutils-0.15.1      | 744 KB    | ########## | 100%
#
# importlib_metadata-0 | 41 KB     |            |   0%
# importlib_metadata-0 | 41 KB     | ########## | 100%
#
# conda-build-3.18.9   | 531 KB    |            |   0%
# conda-build-3.18.9   | 531 KB    | #8         |  18%
# conda-build-3.18.9   | 531 KB    | ####2      |  42%
# conda-build-3.18.9   | 531 KB    | ######6    |  66%
# conda-build-3.18.9   | 531 KB    | #########  |  90%
# conda-build-3.18.9   | 531 KB    | ########## | 100%
#
# anaconda-custom      | 3 KB      |            |   0%
# anaconda-custom      | 3 KB      | ########## | 100%
#
# json5-0.8.5          | 25 KB     |            |   0%
# json5-0.8.5          | 25 KB     | ########## | 100%
#
# soupsieve-1.9.2      | 61 KB     |            |   0%
# soupsieve-1.9.2      | 61 KB     | ########## | 100%
#
# python-3.7.4         | 18.2 MB   |            |   0%
# python-3.7.4         | 18.2 MB   |            |   0%
# python-3.7.4         | 18.2 MB   |            |   1%
# python-3.7.4         | 18.2 MB   | 1          |   1%
# python-3.7.4         | 18.2 MB   | 1          |   2%
# python-3.7.4         | 18.2 MB   | 2          |   2%
# python-3.7.4         | 18.2 MB   | 3          |   3%
# python-3.7.4         | 18.2 MB   | 3          |   4%
# python-3.7.4         | 18.2 MB   | 4          |   4%
# python-3.7.4         | 18.2 MB   | 4          |   5%
# python-3.7.4         | 18.2 MB   | 5          |   5%
# python-3.7.4         | 18.2 MB   | 6          |   6%
# python-3.7.4         | 18.2 MB   | 6          |   7%
# python-3.7.4         | 18.2 MB   | 7          |   7%
# python-3.7.4         | 18.2 MB   | 8          |   8%
# python-3.7.4         | 18.2 MB   | 8          |   9%
# python-3.7.4         | 18.2 MB   | 9          |  10%
# python-3.7.4         | 18.2 MB   | #          |  10%
# python-3.7.4         | 18.2 MB   | #1         |  11%
# python-3.7.4         | 18.2 MB   | #1         |  12%
# python-3.7.4         | 18.2 MB   | #2         |  12%
# python-3.7.4         | 18.2 MB   | #3         |  13%
# python-3.7.4         | 18.2 MB   | #3         |  14%
# python-3.7.4         | 18.2 MB   | #4         |  15%
# python-3.7.4         | 18.2 MB   | #5         |  15%
# python-3.7.4         | 18.2 MB   | #5         |  16%
# python-3.7.4         | 18.2 MB   | #6         |  17%
# python-3.7.4         | 18.2 MB   | #7         |  17%
# python-3.7.4         | 18.2 MB   | #8         |  18%
# python-3.7.4         | 18.2 MB   | #8         |  19%
# python-3.7.4         | 18.2 MB   | #9         |  19%
# python-3.7.4         | 18.2 MB   | ##         |  20%
# python-3.7.4         | 18.2 MB   | ##         |  21%
# python-3.7.4         | 18.2 MB   | ##1        |  22%
# python-3.7.4         | 18.2 MB   | ##2        |  22%
# python-3.7.4         | 18.2 MB   | ##3        |  23%
# python-3.7.4         | 18.2 MB   | ##3        |  24%
# python-3.7.4         | 18.2 MB   | ##4        |  25%
# python-3.7.4         | 18.2 MB   | ##5        |  25%
# python-3.7.4         | 18.2 MB   | ##6        |  26%
# python-3.7.4         | 18.2 MB   | ##6        |  27%
# python-3.7.4         | 18.2 MB   | ##7        |  27%
# python-3.7.4         | 18.2 MB   | ##8        |  28%
# python-3.7.4         | 18.2 MB   | ##8        |  29%
# python-3.7.4         | 18.2 MB   | ##9        |  30%
# python-3.7.4         | 18.2 MB   | ###        |  30%
# python-3.7.4         | 18.2 MB   | ###        |  31%
# python-3.7.4         | 18.2 MB   | ###1       |  32%
# python-3.7.4         | 18.2 MB   | ###2       |  32%
# python-3.7.4         | 18.2 MB   | ###2       |  33%
# python-3.7.4         | 18.2 MB   | ###3       |  34%
# python-3.7.4         | 18.2 MB   | ###4       |  34%
# python-3.7.4         | 18.2 MB   | ###5       |  35%
# python-3.7.4         | 18.2 MB   | ###5       |  36%
# python-3.7.4         | 18.2 MB   | ###6       |  37%
# python-3.7.4         | 18.2 MB   | ###7       |  37%
# python-3.7.4         | 18.2 MB   | ###8       |  38%
# python-3.7.4         | 18.2 MB   | ###8       |  39%
# python-3.7.4         | 18.2 MB   | ###9       |  40%
# python-3.7.4         | 18.2 MB   | ####       |  40%
# python-3.7.4         | 18.2 MB   | ####       |  41%
# python-3.7.4         | 18.2 MB   | ####1      |  42%
# python-3.7.4         | 18.2 MB   | ####2      |  42%
# python-3.7.4         | 18.2 MB   | ####3      |  43%
# python-3.7.4         | 18.2 MB   | ####3      |  44%
# python-3.7.4         | 18.2 MB   | ####4      |  44%
# python-3.7.4         | 18.2 MB   | ####5      |  45%
# python-3.7.4         | 18.2 MB   | ####5      |  46%
# python-3.7.4         | 18.2 MB   | ####6      |  47%
# python-3.7.4         | 18.2 MB   | ####7      |  47%
# python-3.7.4         | 18.2 MB   | ####7      |  48%
# python-3.7.4         | 18.2 MB   | ####8      |  49%
# python-3.7.4         | 18.2 MB   | ####9      |  49%
# python-3.7.4         | 18.2 MB   | #####      |  50%
# python-3.7.4         | 18.2 MB   | #####      |  51%
# python-3.7.4         | 18.2 MB   | #####1     |  52%
# python-3.7.4         | 18.2 MB   | #####2     |  52%
# python-3.7.4         | 18.2 MB   | #####2     |  53%
# python-3.7.4         | 18.2 MB   | #####3     |  54%
# python-3.7.4         | 18.2 MB   | #####4     |  54%
# python-3.7.4         | 18.2 MB   | #####5     |  55%
# python-3.7.4         | 18.2 MB   | #####5     |  56%
# python-3.7.4         | 18.2 MB   | #####6     |  57%
# python-3.7.4         | 18.2 MB   | #####7     |  57%
# python-3.7.4         | 18.2 MB   | #####8     |  58%
# python-3.7.4         | 18.2 MB   | #####9     |  59%
# python-3.7.4         | 18.2 MB   | #####9     |  60%
# python-3.7.4         | 18.2 MB   | ######     |  61%
# python-3.7.4         | 18.2 MB   | ######1    |  61%
# python-3.7.4         | 18.2 MB   | ######1    |  62%
# python-3.7.4         | 18.2 MB   | ######2    |  63%
# python-3.7.4         | 18.2 MB   | ######3    |  63%
# python-3.7.4         | 18.2 MB   | ######4    |  64%
# python-3.7.4         | 18.2 MB   | ######4    |  65%
# python-3.7.4         | 18.2 MB   | ######5    |  65%
# python-3.7.4         | 18.2 MB   | ######6    |  66%
# python-3.7.4         | 18.2 MB   | ######7    |  67%
# python-3.7.4         | 18.2 MB   | ######7    |  68%
# python-3.7.4         | 18.2 MB   | ######8    |  69%
# python-3.7.4         | 18.2 MB   | ######9    |  69%
# python-3.7.4         | 18.2 MB   | #######    |  70%
# python-3.7.4         | 18.2 MB   | #######    |  71%
# python-3.7.4         | 18.2 MB   | #######1   |  72%
# python-3.7.4         | 18.2 MB   | #######2   |  72%
# python-3.7.4         | 18.2 MB   | #######3   |  73%
# python-3.7.4         | 18.2 MB   | #######3   |  74%
# python-3.7.4         | 18.2 MB   | #######4   |  74%
# python-3.7.4         | 18.2 MB   | #######5   |  75%
# python-3.7.4         | 18.2 MB   | #######5   |  76%
# python-3.7.4         | 18.2 MB   | #######6   |  77%
# python-3.7.4         | 18.2 MB   | #######7   |  77%
# python-3.7.4         | 18.2 MB   | #######8   |  78%
# python-3.7.4         | 18.2 MB   | #######8   |  79%
# python-3.7.4         | 18.2 MB   | #######9   |  79%
# python-3.7.4         | 18.2 MB   | ########   |  80%
# python-3.7.4         | 18.2 MB   | ########   |  81%
# python-3.7.4         | 18.2 MB   | ########1  |  82%
# python-3.7.4         | 18.2 MB   | ########2  |  82%
# python-3.7.4         | 18.2 MB   | ########3  |  83%
# python-3.7.4         | 18.2 MB   | ########3  |  84%
# python-3.7.4         | 18.2 MB   | ########4  |  85%
# python-3.7.4         | 18.2 MB   | ########5  |  85%
# python-3.7.4         | 18.2 MB   | ########5  |  86%
# python-3.7.4         | 18.2 MB   | ########6  |  87%
# python-3.7.4         | 18.2 MB   | ########7  |  87%
# python-3.7.4         | 18.2 MB   | ########7  |  88%
# python-3.7.4         | 18.2 MB   | ########8  |  89%
# python-3.7.4         | 18.2 MB   | ########9  |  89%
# python-3.7.4         | 18.2 MB   | #########  |  90%
# python-3.7.4         | 18.2 MB   | #########  |  91%
# python-3.7.4         | 18.2 MB   | #########1 |  91%
# python-3.7.4         | 18.2 MB   | #########2 |  92%
# python-3.7.4         | 18.2 MB   | #########2 |  93%
# python-3.7.4         | 18.2 MB   | #########3 |  94%
# python-3.7.4         | 18.2 MB   | #########4 |  94%
# python-3.7.4         | 18.2 MB   | #########5 |  95%
# python-3.7.4         | 18.2 MB   | #########5 |  96%
# python-3.7.4         | 18.2 MB   | #########6 |  96%
# python-3.7.4         | 18.2 MB   | #########7 |  97%
# python-3.7.4         | 18.2 MB   | #########7 |  98%
# python-3.7.4         | 18.2 MB   | #########8 |  99%
# python-3.7.4         | 18.2 MB   | #########9 |  99%
# python-3.7.4         | 18.2 MB   | #########9 | 100%
# python-3.7.4         | 18.2 MB   | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %%
rev = pd.read_csv("revenue.csv", index_col = "Date")
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
s = pd.Series([1, 2, 3])
s.sum()
# Out:
# 6

# %%
rev.sum(axis = "columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# ## Select One Column from a `DataFrame`

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %% [markdown]
# ## Select Two or More Columns from A `DataFrame`

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba[["Team", "Name"]].head(3)
nba[["Number", "College"]]
nba[["Salary", "Team", "Name"]].tail()
# Out:
#         Salary       Team          Name
# 453  2433333.0  Utah Jazz  Shelvin Mack
# 454   900000.0  Utah Jazz     Raul Neto
# 455  2900000.0  Utah Jazz  Tibor Pleiss
# 456   947276.0  Utah Jazz   Jeff Withey
# 457        NaN        NaN           NaN

# %%
select = ["Salary", "Team", "Name"]
nba[select]
# Out:
#          Salary                    Team                     Name
# 0     7730337.0          Boston Celtics            Avery Bradley
# 1     6796117.0          Boston Celtics              Jae Crowder
# 2           NaN          Boston Celtics             John Holland
# 3     1148640.0          Boston Celtics              R.J. Hunter
# 4     5000000.0          Boston Celtics            Jonas Jerebko
# 5    12000000.0          Boston Celtics             Amir Johnson
# 6     1170960.0          Boston Celtics            Jordan Mickey
# 7     2165160.0          Boston Celtics             Kelly Olynyk
# 8     1824360.0          Boston Celtics             Terry Rozier
# 9     3431040.0          Boston Celtics             Marcus Smart
# 10    2569260.0          Boston Celtics          Jared Sullinger
# 11    6912869.0          Boston Celtics            Isaiah Thomas
# 12    3425510.0          Boston Celtics              Evan Turner
# 13    1749840.0          Boston Celtics              James Young
# 14    2616975.0          Boston Celtics             Tyler Zeller
# 15    3425510.0           Brooklyn Nets         Bojan Bogdanovic
# 16     845059.0           Brooklyn Nets             Markel Brown
# 17    1500000.0           Brooklyn Nets          Wayne Ellington
# 18    1335480.0           Brooklyn Nets  Rondae Hollis-Jefferson
# 19    6300000.0           Brooklyn Nets             Jarrett Jack
# 20    1599840.0           Brooklyn Nets           Sergey Karasev
# 21     134215.0           Brooklyn Nets          Sean Kilpatrick
# 22    1500000.0           Brooklyn Nets             Shane Larkin
# 23   19689000.0           Brooklyn Nets              Brook Lopez
# 24    1140240.0           Brooklyn Nets         Chris McCullough
# 25     947276.0           Brooklyn Nets              Willie Reed
# 26     981348.0           Brooklyn Nets          Thomas Robinson
# 27     947276.0           Brooklyn Nets               Henry Sims
# 28     947276.0           Brooklyn Nets             Donald Sloan
# 29   11235955.0           Brooklyn Nets           Thaddeus Young
# ..          ...                     ...                      ...
# 428   8042895.0  Portland Trail Blazers          Al-Farouq Aminu
# 429    625093.0  Portland Trail Blazers          Pat Connaughton
# 430    947276.0  Portland Trail Blazers             Allen Crabbe
# 431   6980802.0  Portland Trail Blazers                 Ed Davis
# 432   2894059.0  Portland Trail Blazers         Maurice Harkless
# 433   6000000.0  Portland Trail Blazers         Gerald Henderson
# 434   5016000.0  Portland Trail Blazers              Chris Kaman
# 435   3075880.0  Portland Trail Blazers           Meyers Leonard
# 436   4236287.0  Portland Trail Blazers           Damian Lillard
# 437   2525160.0  Portland Trail Blazers            C.J. McCollum
# 438    525093.0  Portland Trail Blazers             Luis Montero
# 439   1415520.0  Portland Trail Blazers            Mason Plumlee
# 440   2854940.0  Portland Trail Blazers            Brian Roberts
# 441   2637720.0  Portland Trail Blazers              Noah Vonleh
# 442   4775000.0               Utah Jazz            Trevor Booker
# 443   2658240.0               Utah Jazz               Trey Burke
# 444   9463484.0               Utah Jazz               Alec Burks
# 445   3777720.0               Utah Jazz               Dante Exum
# 446  12000000.0               Utah Jazz           Derrick Favors
# 447   1175880.0               Utah Jazz              Rudy Gobert
# 448  15409570.0               Utah Jazz           Gordon Hayward
# 449   1348440.0               Utah Jazz              Rodney Hood
# 450   2050000.0               Utah Jazz               Joe Ingles
# 451    981348.0               Utah Jazz            Chris Johnson
# 452   2239800.0               Utah Jazz               Trey Lyles
# 453   2433333.0               Utah Jazz             Shelvin Mack
# 454    900000.0               Utah Jazz                Raul Neto
# 455   2900000.0               Utah Jazz             Tibor Pleiss
# 456    947276.0               Utah Jazz              Jeff Withey
# 457         NaN                     NaN                      NaN
#
# [458 rows x 3 columns]

# %% [markdown]
# ## Add New Column to `DataFrame`

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)

nba["Sport"] = "Basketball"
nba.head(3)

nba["League"] = "National Basketball Association"
nba.head(3)

nba = pd.read_csv("nba.csv")
nba.head(3)

nba.insert(3, column = "Sport", value = "Basketball")
nba.head(3)

nba.insert(7, column = "League", value = "National Basketball Association")
Output = None

# %% [markdown]
# ## Broadcasting Operations

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Age"].add(5)
nba["Age"] + 5

nba["Salary"].sub(5000000)
nba["Salary"] - 5000000

nba["Weight"].mul(0.453592)
nba["Weight in Kilograms"] = nba["Weight"] * 0.453592

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in Kilograms
# 0              Texas  7730337.0             81.64656
# 1          Marquette  6796117.0            106.59412
# 2  Boston University        NaN             92.98636

# %%
nba["Salary"].div(1000000)
nba["Salary in Millions"] = nba["Salary"] / 1000000

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in Kilograms  Salary in Millions
# 0              Texas  7730337.0             81.64656            7.730337
# 1          Marquette  6796117.0            106.59412            6.796117
# 2  Boston University        NaN             92.98636                 NaN

# %% [markdown]
# ## A Review of the `.value_counts()` Method

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Team"].value_counts()
nba["Position"].value_counts().head(1)
nba["Weight"].value_counts().tail()
nba["Salary"].value_counts()
# Out:
# 947276.0      31
# 845059.0      18
# 525093.0      13
# 981348.0       6
# 16407500.0     5
# 4000000.0      5
# 5000000.0      5
# 1100602.0      5
# 8000000.0      5
# 12000000.0     5
# 1000000.0      4
# 7000000.0      4
# 2814000.0      4
# 3000000.0      4
# 19689000.0     4
# 2500000.0      3
# 13500000.0     3
# 2854940.0      3
# 8500000.0      3
# 5543725.0      3
# 1015421.0      3
# 200600.0       3
# 14260870.0     2
# 1140240.0      2
# 15851950.0     2
# 55722.0        2
# 1270964.0      2
# 13000000.0     2
# 3425510.0      2
# 2288205.0      2
#               ..
# 2841960.0      1
# 17120106.0     1
# 1142880.0      1
# 4950000.0      1
# 306527.0       1
# 206192.0       1
# 1200000.0      1
# 900000.0       1
# 22875000.0     1
# 4300000.0      1
# 250750.0       1
# 5219169.0      1
# 1160160.0      1
# 2357760.0      1
# 6110034.0      1
# 18671659.0     1
# 22359364.0     1
# 8042895.0      1
# 5192520.0      1
# 25000000.0     1
# 3300000.0      1
# 1749840.0      1
# 1724250.0      1
# 10000000.0     1
# 1320000.0      1
# 5103120.0      1
# 6796117.0      1
# 4088019.0      1
# 10734586.0     1
# 3036927.0      1
# Name: Salary, dtype: int64

# %% [markdown]
# ## Drop Rows with Null Values

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dropna(how = "all", inplace = True)

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.dropna(subset = ["Salary", "College"])
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 26           Thomas Robinson           Brooklyn Nets    41.0       PF  25.0
# 27                Henry Sims           Brooklyn Nets    14.0        C  26.0
# 28              Donald Sloan           Brooklyn Nets    15.0       PG  28.0
# 29            Thaddeus Young           Brooklyn Nets    30.0       PF  27.0
# 30             Arron Afflalo         New York Knicks     4.0       SG  30.0
# 31              Lou Amundson         New York Knicks    17.0       PF  33.0
# 33           Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 35          Cleanthony Early         New York Knicks    11.0       SF  25.0
# 36         Langston Galloway         New York Knicks     2.0       SG  24.0
# ..                       ...                     ...     ...      ...   ...
# 422            Cameron Payne   Oklahoma City Thunder    22.0       PG  21.0
# 423           Andre Roberson   Oklahoma City Thunder    21.0       SG  24.0
# 424             Kyle Singler   Oklahoma City Thunder     5.0       SF  28.0
# 425             Dion Waiters   Oklahoma City Thunder     3.0       SG  24.0
# 426        Russell Westbrook   Oklahoma City Thunder     0.0       PG  27.0
# 427          Cliff Alexander  Portland Trail Blazers    34.0       PF  20.0
# 428          Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 429          Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0
# 430             Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0
# 431                 Ed Davis  Portland Trail Blazers    17.0        C  27.0
# 432         Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0
# 433         Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0
# 434              Chris Kaman  Portland Trail Blazers    35.0        C  34.0
# 435           Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0
# 436           Damian Lillard  Portland Trail Blazers     0.0       PG  25.0
# 437            C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0
# 438             Luis Montero  Portland Trail Blazers    44.0       SG  23.0
# 439            Mason Plumlee  Portland Trail Blazers    24.0        C  26.0
# 440            Brian Roberts  Portland Trail Blazers     2.0       PG  30.0
# 441              Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0
# 442            Trevor Booker               Utah Jazz    33.0       PF  28.0
# 443               Trey Burke               Utah Jazz     3.0       PG  23.0
# 444               Alec Burks               Utah Jazz    10.0       SG  24.0
# 446           Derrick Favors               Utah Jazz    15.0       PF  24.0
# 448           Gordon Hayward               Utah Jazz    20.0       SF  26.0
# 449              Rodney Hood               Utah Jazz     5.0       SG  23.0
# 451            Chris Johnson               Utah Jazz    23.0       SF  26.0
# 452               Trey Lyles               Utah Jazz    41.0       PF  20.0
# 453             Shelvin Mack               Utah Jazz     8.0       PG  26.0
# 456              Jeff Withey               Utah Jazz    24.0        C  26.0
#
#     Height  Weight           College      Salary
# 0      6-2   180.0             Texas   7730337.0
# 1      6-6   235.0         Marquette   6796117.0
# 3      6-5   185.0     Georgia State   1148640.0
# 6      6-8   235.0               LSU   1170960.0
# 7      7-0   238.0           Gonzaga   2165160.0
# 8      6-2   190.0        Louisville   1824360.0
# 9      6-4   220.0    Oklahoma State   3431040.0
# 10     6-9   260.0        Ohio State   2569260.0
# 11     5-9   185.0        Washington   6912869.0
# 12     6-7   220.0        Ohio State   3425510.0
# 13     6-6   215.0          Kentucky   1749840.0
# 14     7-0   253.0    North Carolina   2616975.0
# 16     6-3   190.0    Oklahoma State    845059.0
# 17     6-4   200.0    North Carolina   1500000.0
# 18     6-7   220.0           Arizona   1335480.0
# 19     6-3   200.0      Georgia Tech   6300000.0
# 21     6-4   219.0        Cincinnati    134215.0
# 22    5-11   175.0        Miami (FL)   1500000.0
# 23     7-0   275.0          Stanford  19689000.0
# 24    6-11   200.0          Syracuse   1140240.0
# 25    6-10   220.0       Saint Louis    947276.0
# 26    6-10   237.0            Kansas    981348.0
# 27    6-10   248.0        Georgetown    947276.0
# 28     6-3   205.0         Texas A&M    947276.0
# 29     6-8   221.0      Georgia Tech  11235955.0
# 30     6-5   210.0              UCLA   8000000.0
# 31     6-9   220.0              UNLV   1635476.0
# 33     6-8   240.0          Syracuse  22875000.0
# 35     6-8   210.0     Wichita State    845059.0
# 36     6-2   200.0    Saint Joseph's    845059.0
# ..     ...     ...               ...         ...
# 422    6-3   185.0      Murray State   2021520.0
# 423    6-7   210.0          Colorado   1210800.0
# 424    6-8   228.0              Duke   4500000.0
# 425    6-4   220.0          Syracuse   5138430.0
# 426    6-3   200.0              UCLA  16744218.0
# 427    6-8   240.0            Kansas    525093.0
# 428    6-9   215.0       Wake Forest   8042895.0
# 429    6-5   206.0        Notre Dame    625093.0
# 430    6-6   210.0        California    947276.0
# 431   6-10   240.0    North Carolina   6980802.0
# 432    6-9   215.0        St. John's   2894059.0
# 433    6-5   215.0              Duke   6000000.0
# 434    7-0   265.0  Central Michigan   5016000.0
# 435    7-1   245.0          Illinois   3075880.0
# 436    6-3   195.0       Weber State   4236287.0
# 437    6-4   200.0            Lehigh   2525160.0
# 438    6-7   185.0    Westchester CC    525093.0
# 439   6-11   235.0              Duke   1415520.0
# 440    6-1   173.0            Dayton   2854940.0
# 441    6-9   240.0           Indiana   2637720.0
# 442    6-8   228.0           Clemson   4775000.0
# 443    6-1   191.0          Michigan   2658240.0
# 444    6-6   214.0          Colorado   9463484.0
# 446   6-10   265.0      Georgia Tech  12000000.0
# 448    6-8   226.0            Butler  15409570.0
# 449    6-8   206.0              Duke   1348440.0
# 451    6-6   206.0            Dayton    981348.0
# 452   6-10   234.0          Kentucky   2239800.0
# 453    6-3   203.0            Butler   2433333.0
# 456    7-0   231.0            Kansas    947276.0
#
# [364 rows x 9 columns]

# %% [markdown]
# ## Fill in Null Values with the `.fillna()` Method

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.fillna(0)
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 26           Thomas Robinson           Brooklyn Nets    41.0       PF  25.0
# 27                Henry Sims           Brooklyn Nets    14.0        C  26.0
# 28              Donald Sloan           Brooklyn Nets    15.0       PG  28.0
# 29            Thaddeus Young           Brooklyn Nets    30.0       PF  27.0
# ..                       ...                     ...     ...      ...   ...
# 428          Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 429          Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0
# 430             Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0
# 431                 Ed Davis  Portland Trail Blazers    17.0        C  27.0
# 432         Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0
# 433         Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0
# 434              Chris Kaman  Portland Trail Blazers    35.0        C  34.0
# 435           Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0
# 436           Damian Lillard  Portland Trail Blazers     0.0       PG  25.0
# 437            C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0
# 438             Luis Montero  Portland Trail Blazers    44.0       SG  23.0
# 439            Mason Plumlee  Portland Trail Blazers    24.0        C  26.0
# 440            Brian Roberts  Portland Trail Blazers     2.0       PG  30.0
# 441              Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0
# 442            Trevor Booker               Utah Jazz    33.0       PF  28.0
# 443               Trey Burke               Utah Jazz     3.0       PG  23.0
# 444               Alec Burks               Utah Jazz    10.0       SG  24.0
# 445               Dante Exum               Utah Jazz    11.0       PG  20.0
# 446           Derrick Favors               Utah Jazz    15.0       PF  24.0
# 447              Rudy Gobert               Utah Jazz    27.0        C  23.0
# 448           Gordon Hayward               Utah Jazz    20.0       SF  26.0
# 449              Rodney Hood               Utah Jazz     5.0       SG  23.0
# 450               Joe Ingles               Utah Jazz     2.0       SF  28.0
# 451            Chris Johnson               Utah Jazz    23.0       SF  26.0
# 452               Trey Lyles               Utah Jazz    41.0       PF  20.0
# 453             Shelvin Mack               Utah Jazz     8.0       PG  26.0
# 454                Raul Neto               Utah Jazz    25.0       PG  24.0
# 455             Tibor Pleiss               Utah Jazz    21.0        C  26.0
# 456              Jeff Withey               Utah Jazz    24.0        C  26.0
# 457                        0                       0     0.0        0   0.0
#
#     Height  Weight            College      Salary
# 0      6-2   180.0              Texas   7730337.0
# 1      6-6   235.0          Marquette   6796117.0
# 2      6-5   205.0  Boston University         0.0
# 3      6-5   185.0      Georgia State   1148640.0
# 4     6-10   231.0                  0   5000000.0
# 5      6-9   240.0                  0  12000000.0
# 6      6-8   235.0                LSU   1170960.0
# 7      7-0   238.0            Gonzaga   2165160.0
# 8      6-2   190.0         Louisville   1824360.0
# 9      6-4   220.0     Oklahoma State   3431040.0
# 10     6-9   260.0         Ohio State   2569260.0
# 11     5-9   185.0         Washington   6912869.0
# 12     6-7   220.0         Ohio State   3425510.0
# 13     6-6   215.0           Kentucky   1749840.0
# 14     7-0   253.0     North Carolina   2616975.0
# 15     6-8   216.0                  0   3425510.0
# 16     6-3   190.0     Oklahoma State    845059.0
# 17     6-4   200.0     North Carolina   1500000.0
# 18     6-7   220.0            Arizona   1335480.0
# 19     6-3   200.0       Georgia Tech   6300000.0
# 20     6-7   208.0                  0   1599840.0
# 21     6-4   219.0         Cincinnati    134215.0
# 22    5-11   175.0         Miami (FL)   1500000.0
# 23     7-0   275.0           Stanford  19689000.0
# 24    6-11   200.0           Syracuse   1140240.0
# 25    6-10   220.0        Saint Louis    947276.0
# 26    6-10   237.0             Kansas    981348.0
# 27    6-10   248.0         Georgetown    947276.0
# 28     6-3   205.0          Texas A&M    947276.0
# 29     6-8   221.0       Georgia Tech  11235955.0
# ..     ...     ...                ...         ...
# 428    6-9   215.0        Wake Forest   8042895.0
# 429    6-5   206.0         Notre Dame    625093.0
# 430    6-6   210.0         California    947276.0
# 431   6-10   240.0     North Carolina   6980802.0
# 432    6-9   215.0         St. John's   2894059.0
# 433    6-5   215.0               Duke   6000000.0
# 434    7-0   265.0   Central Michigan   5016000.0
# 435    7-1   245.0           Illinois   3075880.0
# 436    6-3   195.0        Weber State   4236287.0
# 437    6-4   200.0             Lehigh   2525160.0
# 438    6-7   185.0     Westchester CC    525093.0
# 439   6-11   235.0               Duke   1415520.0
# 440    6-1   173.0             Dayton   2854940.0
# 441    6-9   240.0            Indiana   2637720.0
# 442    6-8   228.0            Clemson   4775000.0
# 443    6-1   191.0           Michigan   2658240.0
# 444    6-6   214.0           Colorado   9463484.0
# 445    6-6   190.0                  0   3777720.0
# 446   6-10   265.0       Georgia Tech  12000000.0
# 447    7-1   245.0                  0   1175880.0
# 448    6-8   226.0             Butler  15409570.0
# 449    6-8   206.0               Duke   1348440.0
# 450    6-8   226.0                  0   2050000.0
# 451    6-6   206.0             Dayton    981348.0
# 452   6-10   234.0           Kentucky   2239800.0
# 453    6-3   203.0             Butler   2433333.0
# 454    6-1   179.0                  0    900000.0
# 455    7-3   256.0                  0   2900000.0
# 456    7-0   231.0             Kansas    947276.0
# 457      0     0.0                  0         0.0
#
# [458 rows x 9 columns]

# %%
nba["Salary"].fillna(0, inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba["College"].fillna("No College", inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %% [markdown]
# ## The `.astype()` Method

# %%
nba = pd.read_csv("nba.csv").dropna(how = "all")
nba["Salary"].fillna(0, inplace = True)
nba["College"].fillna("None", inplace = True)
nba.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         0.0
# 3      Georgia State   1148640.0
# 4               None   5000000.0
# 5               None  12000000.0

# %%
nba.dtypes
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null category
# Number      457 non-null int64
# Position    457 non-null category
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int64
# dtypes: category(2), float64(1), int64(3), object(3)
# memory usage: 29.7+ KB

# %%
nba["Salary"] = nba["Salary"].astype("int")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Number"] = nba["Number"].astype("int")
nba["Age"] = nba["Age"].astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Age"].astype("float")
# Out:
# 0      25.0
# 1      25.0
# 2      27.0
# 3      22.0
# 4      29.0
# 5      29.0
# 6      21.0
# 7      25.0
# 8      22.0
# 9      22.0
# 10     24.0
# 11     27.0
# 12     27.0
# 13     20.0
# 14     26.0
# 15     27.0
# 16     24.0
# 17     28.0
# 18     21.0
# 19     32.0
# 20     22.0
# 21     26.0
# 22     23.0
# 23     28.0
# 24     21.0
# 25     26.0
# 26     25.0
# 27     26.0
# 28     28.0
# 29     27.0
#        ...
# 427    20.0
# 428    25.0
# 429    23.0
# 430    24.0
# 431    27.0
# 432    23.0
# 433    28.0
# 434    34.0
# 435    24.0
# 436    25.0
# 437    24.0
# 438    23.0
# 439    26.0
# 440    30.0
# 441    20.0
# 442    28.0
# 443    23.0
# 444    24.0
# 445    20.0
# 446    24.0
# 447    23.0
# 448    26.0
# 449    23.0
# 450    28.0
# 451    26.0
# 452    20.0
# 453    26.0
# 454    24.0
# 455    26.0
# 456    26.0
# Name: Age, dtype: float64

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"] = nba["Position"].astype("category")

# %%
nba["Team"] = nba["Team"].astype("category")

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4               None  5000000

# %% [markdown]
# ## Sort a `DataFrame` with the `.sort_values()` Method, Part I

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values("Name", ascending = False)

nba.sort_values("Age", ascending = False)

nba.sort_values("Salary", ascending = False, inplace = True)
nba.head(3)
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
#
#      Weight   College      Salary
# 109   212.0       NaN  25000000.0
# 169   250.0       NaN  22970500.0
# 33    240.0  Syracuse  22875000.0

# %%
nba.sort_values("Salary", ascending = False, na_position = "first").tail()
# Out:
#                        Name                  Team  Number Position   Age  \
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
#
#     Height  Weight           College    Salary
# 175    6-5   179.0         Tennessee  111196.0
# 135    6-8   260.0  UC Santa Barbara   83397.0
# 291    6-5   220.0  UC Santa Barbara   55722.0
# 130   5-11   175.0          Missouri   55722.0
# 32     6-7   205.0               NaN   30888.0

# %% [markdown]
# ## Sort a `DataFrame` with the `.sort_values()` Method, Part II

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values(["Team", "Name"], ascending = [True, False], inplace = True)
nba.head(3)
# Out:
#                  Name           Team  Number Position   Age Height  Weight  \
# 322    Walter Tavares  Atlanta Hawks    22.0        C  24.0    7-3   260.0
# 310  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 321    Tiago Splitter  Atlanta Hawks    11.0        C  31.0   6-11   245.0
#
#       College     Salary
# 322       NaN  1000000.0
# 310  Michigan  1304520.0
# 321       NaN  9756250.0

# %% [markdown]
# ## Sort `DataFrame` with the `.sort_index()` Method

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values(["Number", "Salary", "Name"], inplace = True)
nba.tail(3)
# Out:
#                Name             Team  Number Position   Age Height  Weight  \
# 68   Lucas Nogueira  Toronto Raptors    92.0        C  23.0    7-0   220.0
# 1       Jae Crowder   Boston Celtics    99.0       SF  25.0    6-6   235.0
# 457             NaN              NaN     NaN      NaN   NaN    NaN     NaN
#
#        College     Salary
# 68         NaN  1842000.0
# 1    Marquette  6796117.0
# 457        NaN        NaN

# %%
nba.sort_index(ascending = False, inplace = True)

# %%
nba.head(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
#
#         Salary
# 457        NaN
# 456   947276.0
# 455  2900000.0

# %% [markdown]
# ## Rank Values with the `.rank()` Method

# %%
nba = pd.read_csv("nba.csv").dropna(how = "all")
nba["Salary"] = nba["Salary"].fillna(0).astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Salary Rank"] = nba["Salary"].rank(ascending = False).astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452

# %%
nba.sort_values(by = "Salary", ascending = False)
# Out:
#                        Name                    Team  Number Position   Age  \
# 109             Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0
# 169            LeBron James     Cleveland Cavaliers    23.0       SF  31.0
# 33          Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 251           Dwight Howard         Houston Rockets    12.0        C  30.0
# 339              Chris Bosh              Miami Heat     1.0       PF  32.0
# 100              Chris Paul    Los Angeles Clippers     3.0       PG  31.0
# 414            Kevin Durant   Oklahoma City Thunder    35.0       SF  27.0
# 164            Derrick Rose           Chicago Bulls     1.0       PG  27.0
# 349             Dwyane Wade              Miami Heat     3.0       SG  34.0
# 174              Kevin Love     Cleveland Cavaliers     0.0       PF  27.0
# 98           DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0
# 23              Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 294       LaMarcus Aldridge       San Antonio Spurs    12.0       PF  30.0
# 265              Marc Gasol       Memphis Grizzlies    33.0        C  31.0
# 96            Blake Griffin    Los Angeles Clippers    32.0       PF  27.0
# 315            Paul Millsap           Atlanta Hawks     4.0       PF  31.0
# 199             Paul George          Indiana Pacers    13.0       SF  26.0
# 426       Russell Westbrook   Oklahoma City Thunder     0.0       PG  27.0
# 168            Kyrie Irving     Cleveland Cavaliers     2.0       PG  24.0
# 233         Wesley Matthews        Dallas Mavericks    23.0       SG  29.0
# 301           Kawhi Leonard       San Antonio Spurs     2.0       SF  24.0
# 418             Enes Kanter   Oklahoma City Thunder    11.0        C  24.0
# 153            Jimmy Butler           Chicago Bulls    21.0       SG  26.0
# 220             Greg Monroe         Milwaukee Bucks    15.0        C  26.0
# 189           Tobias Harris         Detroit Pistons    34.0       SF  23.0
# 382               John Wall      Washington Wizards     2.0       PG  25.0
# 143        DeMarcus Cousins        Sacramento Kings    15.0        C  25.0
# 249            James Harden         Houston Rockets    13.0       SG  26.0
# 111             Roy Hibbert      Los Angeles Lakers    17.0        C  29.0
# 288             Eric Gordon    New Orleans Pelicans    10.0       SG  27.0
# ..                      ...                     ...     ...      ...   ...
# 304            Andre Miller       San Antonio Spurs    24.0       PG  40.0
# 73           Jason Thompson         Toronto Raptors     1.0       PF  29.0
# 420           Nazr Mohammed   Oklahoma City Thunder    13.0        C  38.0
# 203               Ty Lawson          Indiana Pacers    10.0       PG  28.0
# 123          Chase Budinger            Phoenix Suns    10.0       SF  28.0
# 248        Andrew Goudelock         Houston Rockets     0.0       PG  27.0
# 381         Marcus Thornton      Washington Wizards    15.0       SF  29.0
# 303            Kevin Martin       San Antonio Spurs    23.0       SG  33.0
# 326         Jorge Gutierrez       Charlotte Hornets    12.0       PG  27.0
# 282      Bryce Dejean-Jones    New Orleans Pelicans    31.0       SG  23.0
# 45              Tony Wroten         New York Knicks     5.0       SG  23.0
# 21          Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 92               Jeff Ayres    Los Angeles Clippers    19.0       PF  29.0
# 184           Lorenzo Brown         Detroit Pistons    17.0       PG  25.0
# 175            Jordan McRae     Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams            Phoenix Suns    15.0        C  23.0
# 130            Phil Pressey            Phoenix Suns    25.0       PG  25.0
# 291         Orlando Johnson    New Orleans Pelicans     0.0       SG  27.0
# 32   Thanasis Antetokounmpo         New York Knicks    43.0       SF  23.0
# 350           Briante Weber              Miami Heat    12.0       PG  23.0
# 46              Elton Brand      Philadelphia 76ers    42.0       PF  37.0
# 2              John Holland          Boston Celtics    30.0       SG  27.0
# 171           Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0
# 397            Axel Toupane          Denver Nuggets     6.0       SG  23.0
# 269            Ray McCallum       Memphis Grizzlies     5.0       PG  24.0
# 353           Dorell Wright              Miami Heat    11.0       SF  30.0
# 264           Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0
# 409              Greg Smith  Minnesota Timberwolves     4.0       PF  25.0
# 273          Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0
# 270          Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
#
#     Height  Weight                College    Salary  Salary Rank
# 109    6-6   212.0                    NaN  25000000            1
# 169    6-8   250.0                    NaN  22970500            2
# 33     6-8   240.0               Syracuse  22875000            3
# 251   6-11   265.0                    NaN  22359364            4
# 339   6-11   235.0           Georgia Tech  22192730            5
# 100    6-0   175.0            Wake Forest  21468695            6
# 414    6-9   240.0                  Texas  20158622            7
# 164    6-3   190.0                Memphis  20093064            8
# 349    6-4   220.0              Marquette  20000000            9
# 174   6-10   251.0                   UCLA  19689000           11
# 98    6-11   265.0              Texas A&M  19689000           11
# 23     7-0   275.0               Stanford  19689000           11
# 294   6-11   240.0                  Texas  19689000           11
# 265    7-1   255.0                    NaN  19688000           14
# 96    6-10   251.0               Oklahoma  18907726           15
# 315    6-8   246.0         Louisiana Tech  18671659           16
# 199    6-9   220.0           Fresno State  17120106           17
# 426    6-3   200.0                   UCLA  16744218           18
# 168    6-3   193.0                   Duke  16407501           19
# 233    6-5   220.0              Marquette  16407500           22
# 301    6-7   230.0        San Diego State  16407500           22
# 418   6-11   245.0               Kentucky  16407500           22
# 153    6-7   220.0              Marquette  16407500           22
# 220   6-11   265.0             Georgetown  16407500           22
# 189    6-9   235.0              Tennessee  16000000           25
# 382    6-4   195.0               Kentucky  15851950           26
# 143   6-11   270.0               Kentucky  15851950           26
# 249    6-5   220.0          Arizona State  15756438           28
# 111    7-2   270.0             Georgetown  15592217           29
# 288    6-4   215.0                Indiana  15514031           30
# ..     ...     ...                    ...       ...          ...
# 304    6-3   200.0                   Utah    250750          428
# 73    6-11   250.0                  Rider    245177          429
# 420   6-10   250.0               Kentucky    222888          430
# 203   5-11   195.0         North Carolina    211744          431
# 123    6-7   209.0                Arizona    206192          432
# 248    6-3   200.0             Charleston    200600          434
# 381    6-4   205.0                    LSU    200600          434
# 303    6-7   199.0       Western Carolina    200600          434
# 326    6-3   189.0             California    189455          436
# 282    6-6   203.0             Iowa State    169883          437
# 45     6-6   205.0             Washington    167406          438
# 21     6-4   219.0             Cincinnati    134215          439
# 92     6-9   250.0          Arizona State    111444          440
# 184    6-5   189.0   North Carolina State    111444          440
# 175    6-5   179.0              Tennessee    111196          442
# 135    6-8   260.0       UC Santa Barbara     83397          443
# 130   5-11   175.0               Missouri     55722          444
# 291    6-5   220.0       UC Santa Barbara     55722          444
# 32     6-7   205.0                    NaN     30888          446
# 350    6-2   165.0  Virginia Commonwealth         0          452
# 46     6-9   254.0                   Duke         0          452
# 2      6-5   205.0      Boston University         0          452
# 171    6-6   225.0                   Duke         0          452
# 397    6-7   210.0                    NaN         0          452
# 269    6-3   190.0                Detroit         0          452
# 353    6-9   205.0                    NaN         0          452
# 264    6-2   180.0                   UCLA         0          452
# 409   6-10   250.0           Fresno State         0          452
# 273   6-10   270.0                    USC         0          452
# 270    6-3   180.0           Rhode Island         0          452
#
# [457 rows x 10 columns]
